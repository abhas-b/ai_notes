# %%
import pyspark.sql.functions as F

df = spark.createDataFrame([("25", "07", "1982")]).toDF("day", "month", "year")

# %%
df.select(F.concat_ws('/', df.year, df.month, df.day).alias("date")).show()
# Out:
# +----------+
# |      date|
# +----------+
# |1982/07/25|
# +----------+

# %%
df.selectExpr("concat_ws('/', year, month, day) as date").show()
# Out:
# +----------+
# |      date|
# +----------+
# |1982/07/25|
# +----------+
